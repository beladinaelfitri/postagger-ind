# %%
import numpy
import io
from itertools import permutations
splitter = '|'

# %%
#Membaca training file dan membuat tag_count, word_tag, tag_trans untuk menghitung transition probability dan emission probability
def read_file_init_table(fname):
    tag_count = {}
    tag_count['<start>'] = 0
    word_tag = {}
    tag_trans = {}
        
    with open(fname) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [l.lower() for l in content]
    content = [x.strip() for x in content]
    idx_line = 0
    is_first_word = 0
    
    while idx_line < len(content):
        prev_tag = '<start>'
        while not content[idx_line].startswith('</kalimat'):
            if  not content[idx_line].startswith('<kalimat'):
                content_part = content[idx_line].split('\t')
                if content_part[1] in tag_count:
                    tag_count[content_part[1]] += 1
                else:
                    tag_count[content_part[1]] = 1
                    
                current_word_tag = content_part[0] + splitter + content_part[1]
                if current_word_tag in word_tag:
                    word_tag[current_word_tag] += 1
                else:    
                    word_tag[current_word_tag] = 1
                    
                if is_first_word == 1:
                    current_tag_trans = '<start>' + splitter + content_part[1]
                    is_first_word = 0
                else:
                    current_tag_trans = prev_tag + splitter + content_part[1]
                    
                if current_tag_trans in tag_trans:
                    tag_trans[current_tag_trans] += 1
                else:
                    tag_trans[current_tag_trans] = 1                    
                prev_tag = content_part[1]                   
            else:
                tag_count['<start>'] += 1
                is_first_word = 1
            idx_line = idx_line + 1

        prev_tag = '<end>'
        if prev_tag in tag_count:
            tag_count[prev_tag] += 1
        else:
            tag_count[prev_tag] = 1
        current_tag_trans = content_part[1]+splitter+prev_tag
        if current_tag_trans in tag_trans:
            tag_trans[current_tag_trans] += 1
        else:
            tag_trans[current_tag_trans] = 1                     
            
        idx_line = idx_line+1       
    return tag_count, word_tag, tag_trans

# %%
#Membaca datatest dan menjadikan array yang berisi kata-kata yang sudah di-split di satu kalimat 
#beserta kumpulan tag dari kata-kata tersebut, kemudian dirubah ke lower-case
def read_datatest(fname):
    sentences = []
    tags = []
    with open(fname) as f:
        content = f.readlines()
    content = [x.strip() for x in content]
    content = [x.lower() for x in content]
    idx_line = 0
    while idx_line < len(content):
        sen = []
        tag = []
        while not content[idx_line].startswith('</kalimat'):
            if  not content[idx_line].startswith('<kalimat'):
                content_part = content[idx_line].split('\t')
                sen.append(content_part[0])
                tag.append(content_part[1])
            idx_line = idx_line + 1
        sentences.append(sen)
        tags.append(tag)
        idx_line = idx_line+2        
    return sentences, tags

# %%
tag_count, word_tag, tag_trans = read_file_init_table('Indonesian_Manually_Tagged_Corpus_ID.tsv')

print(tag_count)
print(word_tag)
print(tag_trans)
# Out:
# {'<start>': 10030, 'nn': 61940, 'sc': 13080, 'vb': 31733, '<end>': 10030, 'nnp': 34649, 'jj': 9724, 'rb': 4903, 'in': 21311, 'z': 26347, 'cd': 17819, 'cc': 7438, 'pr': 5348, 'prp': 7583, 'md': 5248, 'fw': 2366, 'neg': 1520, 'dt': 381, 'nnd': 1414, 'sym': 2210, 'rp': 183, 'wh': 260, 'od': 738, 'x': 397, 'uh': 30}
|rb': 809, 'kesulitan|vb': 9, 'mengatasi|vb': 36, 'wabah|nn': 1, 'demam berdarah|nn': 1, 'curah|nn': 1, 'hujan|nn': 5, 'tinggi|jj': 318, 'menyebabkan|vb': 46, 'banyak|cd': 247, 'genangan|nn': 2, 'tempat|nn': 104, 'ideal|jj': 6, 'bagi|in': 341, 'nyamuk|nn': 3, 'aedes|nnp': 1, 'berkembang biak|vb': 1, 'telah|md': 836, 'menempatkan|vb': 38, 'ikan|nn': 8, 'berbagai|cd': 169, 'air|nn': 39, 'memangsa|vb': 1, 'telur|nn': 1, 'miliarder|nn': 3, 'as|nnp': 1544, 'jamu|vb': 1, 'orang kaya|nn': 1, 'cina|nnp': 20, 'amerika|nnp': 217, 'bill|nnp': 5, 'gates|nnp': 10, 'warren|nnp': 1, 'buffett|nnp': 2, 'mengadakan|vb': 48, 'jamuan|nn': 5, 'makan malam|nn': 5, 'beijing|nnp': 15, 'sejumlah|cd': 172, 'orang|nn': 489, 'terkaya|jj': 3, 'mengatakan|vb': 932, 'mempelajari|vb': 4, 'kegiatan|nn': 89, 'amal|nn': 5, 'negara|nn': 618, 'itu|pr': 2273, 'menduga|vb': 9, 'ingin|rb': 83, 'membujuk|vb': 9, 'para|dt': 365, 'tamu|nn': 4, 'agar|sc': 156, 'menyumbang|vb': 27, 'untuk|in': 463, 'kedua|cd': 120, 'dunia|nn': 221, 'sudah|md': 290, 'berhasil|vb': 84, 'sangat|rb': 226, 'kaya|jj': 15, 'menyumbangkan|vb': 5, 'separuh|cd': 6, 'kekayaan|nn': 9, 'ada|vb': 415, 'kerahasiaan|nn': 2, 'mengenai|in': 253, 'acara|nn': 37, 'pihak|nn': 289, 'penyelenggara|nn': 4, 'membeberkan|vb': 2, 'nama-nama|nn': 5, 'salah satu|cd': 116, 'menghadiri|vb': 16, 'adalah|vb': 486, 'chen|nnp': 1, 'guangbiao|nnp': 1, 'seorang|nnd': 361, 'meraup|vb': 1, 'bisnis|nn': 67, 'mendaur ulang|vb': 1, 'sampah|nn': 2, 'industri|nn': 142, 'bangunan|nn': 37, 'dia|prp': 532, 'bbc|nnp': 7, 'bahwa|sc': 705, 'seluruh|cd': 156, 'harta|nn': 5, '-nya|prp': 4648, 'bila|sc': 45, 'meninggal|vb': 41, 'beramal|vb': 2, 'membantu|vb': 85, 'menjadi|vb': 980, 'ba ...
# {'<start>|nn': 3218, 'nn|sc': 4612, 'sc|vb': 5581, 'vb|nn': 11203, 'nn|<end>': 54, '<start>|nnp': 1741, 'nnp|nnp': 14512, 'nnp|vb': 2939, 'nn|jj': 4568, 'jj|sc': 898, 'vb|rb': 527, 'rb|jj': 1058, 'jj|in': 1476, 'in|nn': 11414, 'nn|nnp': 6132, 'nnp|z': 8003, 'z|<end>': 9818, '<start>|cd': 420, 'cd|nn': 4649, 'nn|vb': 3557, 'rb|cd': 248, 'vb|in': 5056, 'nn|nn': 18021, 'nn|cc': 2346, 'cc|nn': 2737, 'nn|in': 5535, 'in|nnp': 4456, 'vb|c
': 88, 'nn|dt': 32, 'prp|cd': 163, 'pr|in': 358, 'jj|nnp': 404, 'nnp|dt': 3, 'cc|cc': 52, 'cc|cd': 494, 'sc|neg': 213, 'sc|od': 29, 'od|z': 129, 'vb|fw': 191, 'fw|fw': 853, 'fw|prp': 25, 'rb|nn': 286, 'pr|rp': 38, 'rp|sc': 30, 'pr|jj': 107, 'in|rb': 102, 'nnd|vb': 54, 'z|fw': 195, 'fw|z': 374, 'z|dt': 27, 'dt|vb': 7, 'rb|nnp': 35, 'in|dt': 94, 'nn|fw': 453, 'fw|in': 183, 'in|od': 20, 'od|nnd': 26, 'fw|nn': 180, 'neg|cd': 20, 'z|in': 932, 'vb|pr': 157, 'nn|nnd': 59, 'cc|sc': 180, 'nnd|cc': 29, 'cd|fw': 57, 'nnd|in': 119, 'nnd|cd': 8, 'cc|in': 322, 'cc|jj': 296, 'in|x': 31, 'x|cd': 15, 'pr|cc': 88, 'sc|rp': 4, 'md|z': 21, 'jj|fw': 41, 'fw|cc': 86, 'rb|sc': 126, 'neg|nn': 71, 'prp|wh': 1, 'wh|prp': 21, 'cd|sym': 112, 'sym|in': 48, 'sym|vb': 18, 'nn|rp': 16, 'cd|prp': 88, 'prp|pr': 41, '<start>|pr': 157, 'sc|x': 12, 'x|jj': 19, 'vb|sym': 612, 'in|fw': 140, 'nn|sym': 481, 'neg|z': 27, 'fw|nnp': 145, 'jj|cd': 632, 'nnd|md': 11, 'nn|od': 579, 'cd|md': 134, 'md|cd': 36, 'in|vb': 532, 'in|pr': 216, 'jj|od': 32, 'od|sc': 47, '<start>|uh': 11, 'uh|prp': 6, 'rb|pr': 16, 'pr|prp': 60, 'fw|pr': 57, 'md|jj': 240, 'sc|pr': 274, 'pr|nnp': 95, 'md|nn': 76, 'jj|sym': 381, 'cd|jj': 237, 'rb|cc': 28, 'od|in': 82, 'od|cc': 14, 'nnd|nnd': 45, 'in|sym': 291, 'cd|pr': 85, 'nnd|rb': 13, 'od|vb': 52, 'od|cd': 181, 'nnp|fw': 197, 'cd|<end>': 29, 'sc|cd': 295, 'z|sym': 46, 'sym|z': 63, 'sym|jj': 11, 'in|z': 58, 'fw|sc': 128, 'od|jj': 11, 'cc|pr': 93, 'sc|fw': 46, 'fw|cd': 44, 'sc|z': 93, 'pr|fw': 6, 'cc|sym': 57, 'prp|rp': 6 ...

# %%
#Menghitung transition probability
def create_trans_prob_table(tag_trans, tag_count):
    trans_prob = {}
    for tag1 in tag_count.keys():
        for tag2 in tag_count.keys():
            trans_idx = tag1+splitter+tag2
            if trans_idx in tag_trans:
                trans_prob[trans_idx] = tag_trans[trans_idx]/tag_count[tag1]
    return trans_prob

# %%
trans_prob = create_trans_prob_table(tag_trans, tag_count)
print(trans_prob)
# Out:
': 0.0030567547978445153, 'vb|od': 0.00025210348848202186, 'vb|x': 0.0014495950587716257, 'vb|uh': 3.151293606025273e-05, 'nnp|nn': 0.02470489768824497, 'nnp|sc': 0.03650899015844613, 'nnp|vb': 0.08482207278709342, 'nnp|<end>': 0.0012410170567693152, 'nnp|nnp': 0.41882882622875117, 'nnp|jj': 0.006493693901699905, 'nnp|rb': 0.011948396779127825, 'nnp|in': 0.07674103148720021, 'nnp|z': 0.23097347686801928, 'nnp|cd': 0.027850731622846257, 'nnp|cc': 0.035123668792750154, 'nnp|pr': 0.010649657998787844, 'nnp|prp': 0.0015296256746226442, 'nnp|md': 0.019394499119743714, 'nnp|fw': 0.005685589771710583, 'nnp|neg': 0.004155964097087939, 'nnp|dt': 8.658258535599873e-05, 'nnp|nnd': 2.886086178533291e-05, 'nnp|sym': 0.0013853213656959797, 'nnp|rp': 0.00017316517071199746, 'nnp|od': 0.0011832953331986492, 'nnp|x': 0.00046177378856532655, 'nnp|uh': 2.886086178533291e-05, 'jj|nn': 0.10180995475113122, 'jj|sc': 0.09234882764294529, 'jj|vb': 0.08946935417523653, 'jj|<end>': 0.002365281777046483, 'jj|nnp': 0.04154668860551213, 'jj|jj': 0.028897573015220075, 'jj|rb': 0.019333607568901 ...

# %%
#Menghitung emission probability
def create_emission_prob_table(word_tag, tag_count):
    emission_prob = {}
    for word_tag_entry in word_tag.keys():
        word_tag_split = word_tag_entry.split(splitter)
        current_word = word_tag_split[0]
        current_tag = word_tag_split[1]
        if word_tag_entry != '' and current_tag != '' :
            emission_key = current_word+splitter+current_tag
            emission_prob[emission_key] = word_tag[word_tag_entry]/tag_count[current_tag]    
    return emission_prob

# %%
emission_prob = create_emission_prob_table(word_tag, tag_count)
print(emission_prob)
# Out:
# {'kera|nn': 1.614465611882467e-05, 'untuk|sc': 0.1375382262996942, 'amankan|vb': 9.45388081807582e-05, 'pesta olahraga|nn': 1.614465611882467e-05, 'pemerintah|nnp': 0.0022222863574706342, 'kota|nnp': 0.0015296256746226442, 'delhi|nnp': 0.0003463303414239949, 'mengerahkan|vb': 9.45388081807582e-05, 'monyet|nn': 0.00024216984178237002, 'mengusir|vb': 0.0003466422966627801, 'monyet-monyet|nn': 3.228931223764934e-05, 'lain|jj': 0.046688605512134926, 'yang|sc': 0.43027522935779816, 'berbadan|vb': 0.00012605174424101093, 'lebih|rb': 0.14950030593514174, 'kecil|jj': 0.014705882352941176, 'dari|in': 0.11304021397400403, 'arena|nn': 3.228931223764934e-05, 'pesta olahraga|nnp': 2.886086178533291e-05, 'persemakmuran|nnp': 2.886086178533291e-05, '.|z': 0.37655141002770715, 'beberapa|cd': 0.018912396879735113, 'laporan|nn': 0.003358088472715531, 'menyebutkan|vb': 0.0028676771814829987, 'setidaknya|rb': 0.0022435243728329596, '10|cd': 0.009596498119984287, 'ditempatkan|vb': 0.0007563104654460656, 'di|in': 0.19595514053775046, 'luar|nn': 0.0010009686793671295, 'lomba|nn': 1.614465611882467e-05, 'dan|cc': 0.6185802
# %%
#Mencari key dari suatu kata di dalam tabel transition probability atau emission probability
def has_key(dictionary, string):
    return [k for k,v in dictionary.items() if (string) == k.split('|')[0]]

# %%
def viterbi(trans_prob, emission_prob, sentence_words):
    #initialization
    viterbi_mat = [{}]
    tag_sequence = [{}]
    
    #Mencari tag untuk kata pertama setelah start
    key_emis = has_key(emission_prob, sentence_words[0])
    tag_em = [k.split('|')[1] for k in key_emis]
    key_trans = has_key(trans_prob, '<start>')
    tag_tr = [k.split('|')[1] for k in key_trans]
    
    #Menghitung probabilitas setiap tag dari start
    for j in range(0,len(tag_em)):
        if tag_em[j] in tag_tr:
            prob = (emission_prob.get(key_emis[j]) * trans_prob.get('<start>|'+tag_em[j]))
            viterbi_mat[0][tag_em[j]] = prob

    #HMM untuk tag kata dari kata kedua sampai kata terakhir
    for i in range(1,len(sentence_words)):
        viterbi_mat.append({})
        tag_sequence.append({})
        
        #Mencai tag untuk kata ke-i
        key_emis = has_key(emission_prob, sentence_words[i])
        tag_em = [k.split('|')[1] for k in key_emis]
        
        #Menghitung probabilitas tag dari tag sebelumnya dan mencari probabilitas terbesar tag
        for j in range(0,len(tag_em)):
            prob = {}
            for k in viterbi_mat[i-1] :
                if(trans_prob.get(k+'|'+tag_em[j])) == None:
                    prob[k] = 0
                else:
                    prob[k] = viterbi_mat[i-1][k] * trans_prob.get(k+'|'+tag_em[j]) * emission_prob.get(key_emis[j])
            viterbi_mat[i][tag_em[j]] = max(prob.values())
            tag_sequence[i][tag_em[j]] = max(prob, key = prob.get)

    #Menghitung probabilitas kata terakhir ke end
    prob = {}
    viterbi_mat.append({})
    for k in viterbi_mat[i]:
        key_trans = [k for k,v in trans_prob.items() if k.endswith('<end>')]
        tag_tr = [k.split('|')[0] for k in key_trans]
        if k in tag_tr:
            prob[k] = viterbi_mat[i][k] * trans_prob.get(k+'|'+'<end>')
        else:
            prob[k] = 0
    
    #Backward mencari tag kata dengan probabilitas yang terbesar
    m = 0
    tag = []
    tag.append(max(prob, key = prob.get))
    for l in range(len(tag_sequence)-1,0,-1):
        tag.append(tag_sequence[l].get(tag[m]))
        m += 1
    tag.reverse()
    
    return tag

# %%
#Membaca datatest
sentences, tags = read_datatest('sample_postagged.txt')

#Predict label dari setiap kata menggunakan viterbi
tag_predicted = []
for s in sentences:
    tag_predicted.append(viterbi(trans_prob, emission_prob, s))

# %%
#Akurasi dihitung dari rata-rata akurasi setiap kalimat
def measure_accuraccy(tag_predicted, tags):
    accu = []
    for predict in range(len(tag_predicted)):
        same = 0
        for p in range(len(tag_predicted[predict])):
            if (tag_predicted[predict][p] == tags[predict][p]):
                same += 1
        accu.append(same / len(tag_predicted[predict]))
    return (sum(accu)/len(accu))

# %%
accuraccy = measure_accuraccy(tag_predicted, tags)
print('Akurasi Viterbi : ', accuraccy)
# Out:
# Akurasi Viterbi :  0.9737406629318395
